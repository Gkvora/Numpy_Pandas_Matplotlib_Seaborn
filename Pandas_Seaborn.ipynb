# %%
import pandas as pd

# %%
#df=pd.read_csv(r'C:\Users\A\addresses.csv')
df=pd.read_csv(r"C:\Users\A\addresses.csv")
df
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
#df2=pd.read_csv('C:\\Users\\A\\annual.csv.csv')

# %%
# df2=pd.read_csv("C://Users//A//annual.csv.csv")
df2=pd.read_csv(r'C://Users//A//annual.csv.csv')
df2
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df1=pd.read_csv(r'C:/Users/A/annual.csv.csv')
df1
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
df.tail()
# Out:
#     id  location_id                   address_1  address_2  \
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
df.head(3)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US

# %%
df.tail(2)
# Out:
#     id  location_id                   address_1  address_2           city  \
# 19  20           21          123 El Camino Real        NaN        Belmont
# 20  21           22  2013 Avenue of the fellows  Suite 100  San Francisco
#
#    state_province postal_code country
# 19             CA       94002      US
# 20             CA       94103      US

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['id',
#  'location_id',
#  'address_1',
#  'address_2',
#  'city',
#  'state_province',
#  'postal_code',
#  'country']

# %%
df.head(3)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US

# %%
df.address_1
# Out:
# 0          2600 Middlefield Road
# 1               24 Second Avenue
# 2               24 Second Avenue
# 3               24 Second Avenue
# 4               24 Second Avenue
# 5              800 Middle Avenue
# 6                 500 Arbor Road
# 7              800 Middle Avenue
# 8          2510 Middlefield Road
# 9          1044 Middlefield Road
# 10           2140 Euclid Avenue.
# 11         1044 Middlefield Road
# 12           399 Marine Parkway.
# 13            660 Veterans Blvd.
# 14          1500 Valencia Street
# 15           1161 South Bernardo
# 16       409 South Spruce Avenue
# 17              114 Fifth Avenue
# 18           19 West 39th Avenue
# 19            123 El Camino Real
# 20    2013 Avenue of the fellows
# Name: address_1, dtype: object

# %%
df['address_1']
# Out:
# 0          2600 Middlefield Road
# 1               24 Second Avenue
# 2               24 Second Avenue
# 3               24 Second Avenue
# 4               24 Second Avenue
# 5              800 Middle Avenue
# 6                 500 Arbor Road
# 7              800 Middle Avenue
# 8          2510 Middlefield Road
# 9          1044 Middlefield Road
# 10           2140 Euclid Avenue.
# 11         1044 Middlefield Road
# 12           399 Marine Parkway.
# 13            660 Veterans Blvd.
# 14          1500 Valencia Street
# 15           1161 South Bernardo
# 16       409 South Spruce Avenue
# 17              114 Fifth Avenue
# 18           19 West 39th Avenue
# 19            123 El Camino Real
# 20    2013 Avenue of the fellows
# Name: address_1, dtype: object

# %%
df.address_1.head()
# Out:
# 0    2600 Middlefield Road
# 1         24 Second Avenue
# 2         24 Second Avenue
# 3         24 Second Avenue
# 4         24 Second Avenue
# Name: address_1, dtype: object

# %%
df['address_1'].head()
# Out:
# 0    2600 Middlefield Road
# 1         24 Second Avenue
# 2         24 Second Avenue
# 3         24 Second Avenue
# 4         24 Second Avenue
# Name: address_1, dtype: object

# %%
df.head(2)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US

# %%
df[['id','address_1','city']]
# Out:
#     id                   address_1                 city
# 0    1       2600 Middlefield Road         Redwood City
# 1    2            24 Second Avenue            San Mateo
# 2    3            24 Second Avenue            San Mateo
# 3    4            24 Second Avenue            San Mateo
# 4    5            24 Second Avenue            San Mateo
# 5    6           800 Middle Avenue           Menlo Park
# 6    7              500 Arbor Road           Menlo Park
# 7    8           800 Middle Avenue           Menlo Park
# 8    9       2510 Middlefield Road         Redwood City
# 9   10       1044 Middlefield Road         Redwood City
# 10  11         2140 Euclid Avenue.         Redwood City
# 11  12       1044 Middlefield Road         Redwood City
# 12  13         399 Marine Parkway.         Redwood City
# 13  14          660 Veterans Blvd.         Redwood City
# 14  15        1500 Valencia Street        San Francisco
# 15  16         1161 South Bernardo            Sunnyvale
# ...

# %%
df[['id',"address_1"]].head(2)
# Out:
#    id              address_1
# 0   1  2600 Middlefield Road
# 1   2       24 Second Avenue

# %%
d1=pd.read_excel(r'C:\Users\A\TEM.xlsx')
d1
# Out:
#          Day  temperature  windspeed  event
# 0 2017-01-01         32.0        6.0   Rain
# 1 2017-01-04         35.0        7.0    NaN
# 2 2017-01-06          NaN        NaN   Snow
# 3 2017-01-09         24.0        7.0    NaN
# 4 2017-01-13         32.0        NaN   Rain
# 5 2017-01-18          NaN        2.0  Sunny
# 6 2017-01-21          NaN        NaN    NaN
# 7 2017-01-28         22.0        NaN   Snow
# 8 2017-01-30         33.0        5.0    NaN

# %%
d2=pd.read_excel('C:\\airline_.xls')
d2
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
d45=pd.read_excel('C:\\airline_.xls',sheet_name='Sheet2')
d45
# Out:
#    YEAR      Y      W       R      L      K
# 0  1948  1.214  0.243  0.1454  1.415  0.612
# 1  1949  1.354  0.260  0.2181  1.384  0.559
# 2  1950  1.569  0.278  0.3157  1.388  0.573
# 3  1951  1.948  0.297  0.3940  1.550  0.564
# 4  1952  2.265  0.310  0.3559  1.802  0.574
# 5  1953  2.731  0.322  0.3593  1.926  0.711
# 6  1954  3.025  0.335  0.4025  1.964  0.776
# 7  1955  3.562  0.350  0.3961  2.116  0.827
# 8  1956  3.979  0.361  0.3822  2.435  0.800

# %%
d45=pd.read_excel('C:\\airline_.xls',sheet_name='gk')
d45
# Out:
#    1964.0000  7.8230     0.5380     0.5163     3.4120     1.9970
# 0       1965      9.120      0.564     0.5879      3.623      2.257
# 1       1966     10.512      0.586     0.5369      4.074      2.742
# 2       1967     13.020      0.622     0.4443      4.710      3.564
# 3       1968     15.261      0.666     0.3052      5.217      4.767
# 4       1969     16.313      0.731     0.2332      5.569      6.511
# 5       1970     16.002      0.831     0.1883      5.495      7.627

# %%
d45=pd.read_excel('C:\\airline_.xls',sheet_name='gk',header=None)
d45
# Out:
#       0       1      2       3      4      5
# 0  1964   7.823  0.538  0.5163  3.412  1.997
# 1  1965   9.120  0.564  0.5879  3.623  2.257
# 2  1966  10.512  0.586  0.5369  4.074  2.742
# 3  1967  13.020  0.622  0.4443  4.710  3.564
# 4  1968  15.261  0.666  0.3052  5.217  4.767
# 5  1969  16.313  0.731  0.2332  5.569  6.511
# 6  1970  16.002  0.831  0.1883  5.495  7.627

# %%
d45=pd.read_excel('C:\\airline_.xls',sheet_name='gk',header=None,names=['a','b','c','d','e','f'])
d45
# Out:
#       a       b      c       d      e      f
# 0  1964   7.823  0.538  0.5163  3.412  1.997
# 1  1965   9.120  0.564  0.5879  3.623  2.257
# 2  1966  10.512  0.586  0.5369  4.074  2.742
# 3  1967  13.020  0.622  0.4443  4.710  3.564
# 4  1968  15.261  0.666  0.3052  5.217  4.767
# 5  1969  16.313  0.731  0.2332  5.569  6.511
# 6  1970  16.002  0.831  0.1883  5.495  7.627

# %%
d45.to_csv('ppppppp.csv',index=False)

# %%
d45.to_excel('gugugugugugu.xlsx')

# %%
dt=pd.read_csv('https://gist.githubusercontent.com/kevin336/acbb2271e66c10a5b73aacf82ca82784/raw/e38afe62e088394d61ed30884dd50a6826eee0a8/employees.csv')

# %%
dt.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20
# 4    MK_REP    6000             -         201             20

# %%
ww=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
ww
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(ww)
# Out:
# list

# %%
ww[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
ww[0].to_csv('sporttt.csv')

# %%
ff=pd.read_csv('C:\\Users\\A\\\sporttt.csv')
ff
# Out:
#      Unnamed: 0   Rk          Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             0    1      Quincy Acy  PF  24  NYK  68  22  1287  152  ...
# 1             1    2    Jordan Adams  SG  20  MEM  30   0   248   35  ...
# 2             2    3    Steven Adams   C  21  OKC  70  67  1771  217  ...
# 3             3    4     Jeff Adrien  PF  28  MIN  17   0   215   19  ...
# 4             4    5   Arron Afflalo  SG  29  TOT  78  72  2502  375  ...
# ..          ...  ...             ...  ..  ..  ...  ..  ..   ...  ...  ...
# 670         670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  ...
# 671         671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  ...
# 672         672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  ...
# 673         673  491     Cody Zeller   C  22  CHO  62  45  1487  172  ...
# 674         674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  ...
#
#       FT%  ORB  DRB  TRB  AST  STL BLK  TOV   PF   PTS
# ...

# %%
d1
# Out:
#          Day  temperature  windspeed  event
# 0 2017-01-01         32.0        6.0   Rain
# 1 2017-01-04         35.0        7.0    NaN
# 2 2017-01-06          NaN        NaN   Snow
# 3 2017-01-09         24.0        7.0    NaN
# 4 2017-01-13         32.0        NaN   Rain
# 5 2017-01-18          NaN        2.0  Sunny
# 6 2017-01-21          NaN        NaN    NaN
# 7 2017-01-28         22.0        NaN   Snow
# 8 2017-01-30         33.0        5.0    NaN

# %%
d1.dtypes
# Out:
# Day            datetime64[ns]
# temperature           float64
# windspeed             float64
# event                  object
# dtype: object

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          9 non-null      datetime64[ns]
#  1   temperature  6 non-null      float64
#  2   windspeed    5 non-null      float64
#  3   event        5 non-null      object
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 416.0+ bytes

# %%
d1.describe()
# Out:
#        temperature  windspeed
# count     6.000000   5.000000
# mean     29.666667   5.400000
# std       5.316641   2.073644
# min      22.000000   2.000000
# 25%      26.000000   5.000000
# 50%      32.000000   6.000000
# 75%      32.750000   7.000000
# max      35.000000   7.000000

# %%
d1['temperature'].describe()
# Out:
# count     6.000000
# mean     29.666667
# std       5.316641
# min      22.000000
# 25%      26.000000
# 50%      32.000000
# 75%      32.750000
# max      35.000000
# Name: temperature, dtype: float64

# %%
import numpy as np
d=np.random.randn(100,3)
d
# Out:
# array([[ 0.12066806,  0.91885514, -0.00422962],
#        [ 0.06735313, -1.14964764, -0.78341322],
#        [ 0.3591753 ,  0.81263899, -0.85101411],
#        [ 0.91879937,  0.85515505,  0.06197454],
#        [-0.13193532,  0.09144382, -0.72120622],
#        [ 1.43540611,  0.9868143 , -1.218859  ],
#        [-0.03908766,  1.10361234, -0.35158306],
#        [ 0.45873361, -0.13960311, -1.20723868],
#        [ 0.25687519, -1.19395733, -0.72250159],
#        [-0.47021388, -1.6374265 ,  0.96451181],
#        [-0.43485631,  0.62362377,  1.05092509],
#        [ 1.71410193, -0.9249999 ,  2.02742814],
#        [ 0.191638  , -0.3629781 , -0.35226608],
#        [-0.54233182,  1.06466791,  0.56055913],
#        [ 1.10166971,  1.72824655, -0.60089583],
#        [ 0.57660196,  0.33744452, -0.06476576],
#        [ 1.02084301, -0.23034674,  0.26925931],
#        [ 0.18735861,  1.37464918,  0.80787956],
#        [-0.74638967, -1.14857712, -0.54351439],
#        [-0.31432081,  0.34069946,  0.18334418],
# ...

# %%
df=pd.DataFrame(d,columns=['a','b','c'])

# %%
df
# Out:
#            a         b         c
# 0   0.120668  0.918855 -0.004230
# 1   0.067353 -1.149648 -0.783413
# 2   0.359175  0.812639 -0.851014
# 3   0.918799  0.855155  0.061975
# 4  -0.131935  0.091444 -0.721206
# ..       ...       ...       ...
# 95  0.078027  0.023725  2.197542
# 96  0.552715  0.490927  0.299180
# 97 -0.410975  1.237641  0.188479
# 98  0.262670  1.334399  0.610158
# 99  0.635014 -0.056616  0.946368
#
# [100 rows x 3 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
tip=sns.load_dataset('tips')
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y='tip',data=tip)

# %%
sns.relplot(x='total_bill',y='tip',data=tip,hue='size')

# %%
sns.relplot(x='total_bill',y='tip',data=tip,hue='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=tip,style='size')

# %%
sns.relplot(x='total_bill',y='tip',data=tip,hue='smoker',style='time')

# %%
sns.relplot(data=tip,kind='line',x='total_bill',y='tip')# aagal pachhal lakhai chale

# %%
sns.relplot(x='total_bill',y='tip',col='time',data=tip)

# %%
sns.relplot(x='total_bill',y='tip',col='size',data=tip)

# %%
sns.catplot(x='day',y='total_bill',data=tip)
