# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
a=[1,2,3,4,5,6,7,8,9]
b=[2,4,2,6,7,8,4,6,7]

# %%
x1=pd.DataFrame({"p":a,"q":b})
x1
# Out:
#    p  q
# 0  1  2
# 1  2  4
# 2  3  2
# 3  4  6
# 4  5  7
# 5  6  8
# 6  7  4
# 7  8  6
# 8  9  7

# %%
sns.lineplot(x="p",y="q",data=x1)
## plt.show()
# Out:
# <AxesSubplot:xlabel='p', ylabel='q'>

# %%
e=[22,33,44,55,66]
f=[33,11,34,10,88]

# %%
sns.lineplot(x=e,y=f)
# Out:
# <AxesSubplot:>

# %%
g=sns.load_dataset("Iris")

# %%
g
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.lineplot(x="sepal_length",y="petal_length",data=g,hue="species")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
g
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.displot(g["sepal_length"],kde=True)

# %%
sns.histplot(g["sepal_length"],kde=True)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(g["sepal_length"])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.displot(g["sepal_length"],kde=True)

# %%
sns.distplot(g["sepal_length"],kde=True)
# Out:
# C:\Users\A\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
g
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.barplot(x="species",y="petal_width",data=g)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
sns.barplot(x=g.species,y=g.petal_width)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
y2=pd.read_csv("C:\\Users\\A\\AM.csv")

# %%
y2
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
sns.barplot(x="Sales_Channel",y="Total_Profit",data=y2,hue="Order_Priority")
# Out:
# <AxesSubplot:xlabel='Sales_Channel', ylabel='Total_Profit'>

# %%
y2
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
sns.relplot(x="Units_Sold",y="Total_Profit",data=y2,hue="Sales_Channel")

# %%
sns.relplot(x="Units_Sold",y="Total_Profit",data=y2,style="Order_Priority")

# %%
sns.relplot(x="Units_Sold",y="Total_Profit",data=y2,style="Order_Priority",hue="Sales_Channel")

# %%
sns.relplot(x="Units_Sold",y="Total_Profit",data=y2,kind="line")

# %%
sns.relplot(x="Units_Sold",y="Total_Profit",data=y2,col="Order_Priority")

# %%
sns.relplot(x="Units_Sold",y="Total_Profit",data=y2,col="Sales_Channel")

# %%
sns.catplot(x="Sales_Channel",y="Total_Profit",data=y2)

# %%
sns.catplot(x="Order_Priority",y="Total_Profit",data=y2)

# %%
sns.catplot(x="Order_Priority",y="Total_Profit",data=y2,kind="swarm")

# %%
sns.catplot(x="Order_Priority",y="Total_Profit",data=y2,kind="box")

# %%
sns.catplot(x="Order_Priority",y="Total_Profit",data=y2,kind="box",hue="Sales_Channel")

# %%
sns.pairplot(y2)

# %%
sns.pairplot(g)

# %%
sns.scatterplot(x="petal_length",y="petal_width",data=g)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sns.hisplot
